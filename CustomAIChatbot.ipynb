# %% [markdown]
# <a href="https://colab.research.google.com/github/chitraju-chaithanya/customAIChatbot/blob/main/CustomAIChatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Custom AI Chatbot**

# %% [markdown]
# One of the main goal here is to retrieve the data from embeddings rather than the GPT 3.5 trained data and use prompt engineering for custom results.
#
#
# 2024 wiki is seleted for embeddings and to evalute the LLM, as GPT 3.5 is not trained with 2024 wiki data.

# %%
# !pip install aiohttp==3.8.3
# !pip install aiosignal==1.3.1
# !pip install appnope==0.1.3
# !pip install asttokens==2.2.1
# !pip install async-timeout==4.0.2
# !pip install attrs==22.2.0
# !pip install backcall==0.2.0
# !pip install beautifulsoup4==4.11.1
# !pip install blobfile==2.0.1
# !pip install bs4==0.0.1
# !pip install certifi==2022.12.7
# !pip install charset-normalizer==2.1.1
# !pip install comm==0.1.2
# !pip install contourpy==1.0.7
# !pip install cycler==0.11.0
# !pip install debugpy==1.6.5
# !pip install decorator==5.1.1
# !pip install docopt==0.6.2
# !pip install entrypoints==0.4
# !pip install executing==1.2.0
# !pip install filelock==3.9.0
# !pip install fonttools==4.38.0
# !pip install frozenlist==1.3.3
# !pip install html==1.13
# !pip install huggingface-hub==0.11.1
# !pip install idna==3.4
# !pip install ipykernel==6.20.1
# !pip install ipython==8.8.0
# !pip install jedi==0.18.2
# !pip install joblib==1.2.0
# !pip install jupyter_client==7.4.8
# !pip install jupyter_core==5.1.3
# !pip install kiwisolver==1.4.4
# !pip install lxml==4.9.2
# !pip install matplotlib==3.6.3
# !pip install matplotlib-inline==0.1.6
# !pip install multidict==6.0.4
# !pip install nest-asyncio==1.5.6
# !pip install numpy==1.24.1
# !pip install openai==0.26.1
# !pip install packaging==23.0
# !pip install pandas==1.5.2
# !pip install parso==0.8.3
# !pip install pexpect==4.8.0
# !pip install pickleshare==0.7.5
# !pip install Pillow==9.4.0
# !pip install pipreqs==0.4.11
# !pip install platformdirs==2.6.2
# !pip install plotly==5.12.0
# !pip install prompt-toolkit==3.0.36
# !pip install psutil==5.9.4
# !pip install ptyprocess==0.7.0
# !pip install pure-eval==0.2.2
# !pip install pycryptodomex==3.17
# !pip install Pygments==2.14.0
# !pip install pyparsing==3.0.9
# !pip install python-dateutil==2.8.2
# !pip install pytz==2022.7.1
# !pip install PyYAML==6.0
# !pip install pyzmq==24.0.1
# !pip install regex==2022.10.31
# !pip install requests==2.28.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 8.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.2
#     Uninstalling charset-normalizer-3.3.2:
#       Successfully uninstalled charset-normalizer-3.3.2
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.9.3
#     Uninstalling aiohttp-3.9.3:
#       Successfully uninstalled aiohttp-3.9.3
# ...
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 4.0.3
#     Uninstalling async-timeout-4.0.3:
#       Successfully uninstalled async-timeout-4.0.3
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 2.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.2.0
#     Uninstalling attrs-23.2.0:
#       Successfully uninstalled attrs-23.2.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 4.3 MB/s eta 0:00:00
# ...

# %%
# !pip install scikit-learn==1.2.0
# !pip install scipy==1.10.0
# !pip install six==1.16.0
# !pip install soupsieve==2.3.2.post1
# !pip install stack-data==0.6.2
# !pip install tenacity==8.1.0
# !pip install threadpoolctl==3.1.0
# !pip install tiktoken==0.1.2
# !pip install tokenizers==0.13.2
# !pip install tornado==6.2
# !pip install tqdm==4.64.1
# !pip install traitlets==5.8.1
# !pip install transformers==4.25.1
# !pip install typing_extensions==4.4.0
# !pip install urllib3==1.26.13
# !pip install wcwidth==0.2.5
# !pip install yarg==0.1.9
# !pip install yarl==1.8.2

# %%
import requests
import re
import urllib.request
from bs4 import BeautifulSoup
from collections import deque
from html.parser import HTMLParser
from urllib.parse import urlparse
import os
import openai

# %%
openai.api_key = "OPEN API KEY"

# %%
current_affairs_2024_prompt_1 = """
Question: "When did Sweden join NATO?"
Answer:
"""
initial_current_affairs_anwser_1 = openai.Completion.create(
    model="gpt-3.5-turbo-instruct",
    prompt=current_affairs_2024_prompt_1,
    max_tokens=150
)["choices"][0]["text"].strip()
print(initial_current_affairs_anwser_1)
# Out:
# Sweden is not currently a member of NATO. It maintains a policy of non-alignment and does not participate in the alliance, although it does cooperate and have strong ties with NATO. This policy has been in place since the end of World War II.

# %%
current_affairs_2024_prompt_2 = """
Question: "Fifth country to land on moon?"
Answer:
"""
initial_current_affairs_anwser_2 = openai.Completion.create(
    model="gpt-3.5-turbo-instruct",
    prompt=current_affairs_2024_prompt_2,
    max_tokens=150
)["choices"][0]["text"].strip()
print(initial_current_affairs_anwser_2)
# Out:
# The fifth country to land on the moon was India with their Chandrayaan-2 mission in September 2019.

# %%
from dateutil.parser import parse
import pandas as pd
import requests

# Get the Wikipedia page for "2024" since OpenAI's models stop in 2021
resp = requests.get("https://en.wikipedia.org/w/api.php?action=query&prop=extracts&exlimit=1&titles=2024&explaintext=1&formatversion=2&format=json")

# Load page text into a dataframe
df = pd.DataFrame()
df["text"] = resp.json()["query"]["pages"][0]["extract"].split("\n")

# Clean up text to remove empty lines and headings
df = df[(df["text"].str.len() > 0) & (~df["text"].str.startswith("=="))]

# In some cases dates are used as headings instead of being part of the
# text sample; adjust so dated text samples start with dates
prefix = ""
for (i, row) in df.iterrows():
    # If the row already has " - ", it already has the needed date prefix
    if " – " not in row["text"]:
        try:
            # If the row's text is a date, set it as the new prefix
            parse(row["text"])
            prefix = row["text"]
        except:
            # If the row's text isn't a date, add the prefix
            row["text"] = prefix + " – " + row["text"]
df = df[df["text"].str.contains(" – ")]
df
# Out:
#                                                   text
# 0     – 2024 (MMXXIV) is the current year, and is a...
# 1     – So far, this year has witnessed the continu...
# 9    January 1 – Egypt, Ethiopia, Iran and the Unit...
# 10   January 1 – The Republic of Artsakh is formall...
# 11   January 1 – A 7.5 Mww earthquake strikes the w...
# ..                                                 ...
# 118     October – 2024 Georgian presidential election.
# 120         November – 2024 Namibian general election.
# 121    November – 2024 Romanian presidential election.
# 122  November – Lee Hsien Loong, Prime Minister of ...
# 123    December – 2024 Croatian presidential election.
#
# [95 rows x 1 columns]

# %%
EMBEDDING_MODEL_NAME = "text-embedding-ada-002"
batch_size = 100
embeddings = []
for i in range(0, len(df), batch_size):
    # Send text data to OpenAI model to get embeddings
    response = openai.Embedding.create(
        input=df.iloc[i:i+batch_size]["text"].tolist(),
        engine=EMBEDDING_MODEL_NAME
    )

    # Add embeddings to list
    embeddings.extend([data["embedding"] for data in response["data"]])

# Add embeddings list to dataframe
df["embeddings"] = embeddings
df
# Out:
#                                                   text  \
# 0     – 2024 (MMXXIV) is the current year, and is a...
# 1     – So far, this year has witnessed the continu...
# 9    January 1 – Egypt, Ethiopia, Iran and the Unit...
# 10   January 1 – The Republic of Artsakh is formall...
# 11   January 1 – A 7.5 Mww earthquake strikes the w...
# ..                                                 ...
# 118     October – 2024 Georgian presidential election.
# 120         November – 2024 Namibian general election.
# 121    November – 2024 Romanian presidential election.
# 122  November – Lee Hsien Loong, Prime Minister of ...
# 123    December – 2024 Croatian presidential election.
#
#                                             embeddings
# 0    [0.00121739087626338, -0.01796046644449234, -0...
# 1    [-0.016559099778532982, -0.023691842332482338,...
# 9    [-0.006015179678797722, -0.023690946400165558,...
# 10   [0.007975899614393711, 0.008091865107417107, -...
# ...

# %%
from openai.embeddings_utils import get_embedding, distances_from_embeddings

def get_rows_sorted_by_relevance(question, df):
    """
    Function that takes in a question string and a dataframe containing
    rows of text and associated embeddings, and returns that dataframe
    sorted from least to most relevant for that question
    """

    # Get embeddings for the question text
    question_embeddings = get_embedding(question, engine=EMBEDDING_MODEL_NAME)

    # Make a copy of the dataframe and add a "distances" column containing
    # the cosine distances between each row's embeddings and the
    # embeddings of the question
    df_copy = df.copy()
    df_copy["distances"] = distances_from_embeddings(
        question_embeddings,
        df_copy["embeddings"].values,
        distance_metric="cosine"
    )

    # Sort the copied dataframe by the distances and return it
    # (shorter distance = more relevant so we sort in ascending order)
    df_copy.sort_values("distances", ascending=True, inplace=True)
    return df_copy

# %%
get_rows_sorted_by_relevance("When did Sweden join NATO?", df)
# Out:
#                                                  text  \
# 49  March 7 – Sweden officially joins NATO, becomi...
# 60  March 31 – Bulgaria and Romania are to become ...
# 77  May 7–11 – Eurovision Song Contest 2024 in Mal...
# 82     June 1 – 2024 Icelandic presidential election.
# 75  April 24 – 2024 North Macedonian presidential ...
# ..                                                ...
# 19  January 13 – 2024 Taiwanese presidential elect...
# 93  October 6 – 2024 Brazilian municipal elections...
# 11  January 1 – A 7.5 Mww earthquake strikes the w...
# 0    – 2024 (MMXXIV) is the current year, and is a...
# 14  January 3 – 2024 Kerman bombings: An Islamic S...
#
#                                            embeddings  distances
# 49  [0.0027264633681625128, -0.038017891347408295,...   0.088365
# 60  [0.011008876375854015, -0.011321230791509151, ...   0.199923
# 77  [-0.012794354930520058, -0.034092970192432404,...   0.204457
# ...

# %%
get_rows_sorted_by_relevance("Fifth country to land on moon?", df)
# Out:
#                                                   text  \
# 24   January 19 – Japan becomes the fifth country t...
# 42   February 22 – American company Intuitive Machi...
# 9    January 1 – Egypt, Ethiopia, Iran and the Unit...
# 97          November 5 – 2024 United States elections.
# 89   July 26 – August 11 – 2024 Summer Olympics in ...
# ..                                                 ...
# 86             June 9 – 2024 Belgian general election.
# 61            March 31 – 2024 Turkish local elections.
# 113  September or October – 2024 Austrian legislati...
# 73    April 17 – 2024 Croatian parliamentary election.
# 106  December 17 – Assuming the next United Kingdom...
#
#                                             embeddings  distances
# 24   [0.007395173888653517, -0.0051426575519144535,...   0.122331
# 42   [0.004740635398775339, -0.013216701336205006, ...   0.164417
# 9    [-0.006015179678797722, -0.023690946400165558,...   0.232417
# ...

# %%
import tiktoken

def create_prompt(question, df, max_token_count):
    """
    Given a question and a dataframe containing rows of text and their
    embeddings, return a text prompt to send to a Completion model
    """
    # Create a tokenizer that is designed to align with our embeddings
    tokenizer = tiktoken.get_encoding("cl100k_base")

    # Count the number of tokens in the prompt template and question
    prompt_template = """
Answer the question based on the context below, and if the question
can't be answered based on the context, say "I don't know"

Context:

{}

---

Question: {}
Answer:"""

    current_token_count = len(tokenizer.encode(prompt_template)) + \
                            len(tokenizer.encode(question))

    context = []
    for text in get_rows_sorted_by_relevance(question, df)["text"].values:

        # Increase the counter based on the number of tokens in this row
        text_token_count = len(tokenizer.encode(text))
        current_token_count += text_token_count

        # Add the row of text to the list if we haven't exceeded the max
        if current_token_count <= max_token_count:
            context.append(text)
        else:
            break

    return prompt_template.format("\n\n###\n\n".join(context), question)

# %%
COMPLETION_MODEL_NAME = "gpt-3.5-turbo-instruct"

def answer_question(
    question, df, max_prompt_tokens=1800, max_answer_tokens=150
):
    """
    Given a question, a dataframe containing rows of text, and a maximum
    number of desired tokens in the prompt and response, return the
    answer to the question according to an OpenAI Completion model

    If the model produces an error, return an empty string
    """

    prompt = create_prompt(question, df, max_prompt_tokens)

    try:
        response = openai.Completion.create(
            model=COMPLETION_MODEL_NAME,
            prompt=prompt,
            max_tokens=max_answer_tokens
        )
        return response["choices"][0]["text"].strip()
    except Exception as e:
        print(e)
        return ""

# %%
custom_current_affairs_anwser_1 = answer_question("When did Sweden join NATO?", df)
print(custom_current_affairs_anwser_1)
# Out:
# March 7

# %%
print(f"""
When did Sweden join NATO?

Original Answer: {initial_current_affairs_anwser_1}
Custom Answer:   {custom_current_affairs_anwser_1}

""")
# Out:
# When did Sweden join NATO?
#
# Original Answer: Sweden is not currently a member of NATO. It maintains a policy of non-alignment and does not participate in the alliance, although it does cooperate and have strong ties with NATO. This policy has been in place since the end of World War II.
# Custom Answer:   March 7

# %%
custom_current_affairs_anwser_2 = answer_question("Fifth country to land on moon?", df)
print(custom_current_affairs_anwser_2)
# Out:
# Japan

# %%
print(f"""
Fifth country to land on moon?

Original Answer: {initial_current_affairs_anwser_2}
Custom Answer:   {custom_current_affairs_anwser_2}

""")
# Out:
# Fifth country to land on moon?
#
# Original Answer: The fifth country to land on the moon was India with their Chandrayaan-2 mission in September 2019.
# Custom Answer:   Japan

# %% [markdown]
# Summary:
#
# In conclusion,achieved better and correct inforamtion from chat applicaiton by using the completion model and prompt engineering,
